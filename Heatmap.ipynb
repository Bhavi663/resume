# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavi663/resume/blob/main/Heatmap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Example dataset
data = {
    "Age": [25, 32, 47, 51, 62],
    "Income": [50000, 64000, 80000, 72000, 85000],
    "Spending Score": [39, 50, 48, 60, 49],
    "Savings": [10000, 15000, 20000, 25000, 30000],
}

# Create a DataFrame
df = pd.DataFrame(data)

# Compute the correlation matrix
correlation_matrix = df.corr()

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Heatmap Example: Correlation Matrix", fontsize=14)
plt.show()
